# %%
import pandas as pd
df=pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
import seaborn as sns

# %%
df["Age"].nunique()
# Out:
# 50

# %%
df["HeartDisease"].unique()
# heart disease has 2 values 1 and 0 meaning has or not
# Out:
# array([0, 1], dtype=int64)

# %%
df["ExerciseAngina"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
# this one means N for no chest pain during exercise while Y means pain happens

# %%
df["ST_Slope"].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
# this one means the heart slope on monitor is either up flat or down

# %%
df["FastingBS"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# this one means after fasting the blood sugar levels are either 0 or 1

# %%
df["Sex"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
# 2 genders male and female

# %%
df["ChestPainType"].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
# These are 4 types of chest pain types people can have

# %%
df["RestingECG"].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
# this means while resting the monitor shows 3 types signal on screen

# %%
sns.countplot(data=df,x="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df["Sex"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# 79% test were done on males while 21% females

# %%
sns.countplot(data=df,x="Sex",hue="HeartDisease")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# This shows males are much more prone to heart disease than female

# %%
df.groupby("Sex")["HeartDisease"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# this shows out of total 100% people 79% are men and out of that 50% is having HD while 30% doesnt
# while out of 21% female 5% have heart disease while 15% doesnt

# %%
# Conclusion is that out of 10 female 2-3 is having HD
# while out of 10 men 6 have HD probability

# %%
50/80
5/20
# Out:
# 0.25

# %%
df_new=df[df["Sex"]=="M"]
df_new["ChestPainType"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df_new=df[df["Sex"]=="F"]
df_new["ChestPainType"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# in both male and female ASY is most common chest pain type and TA is least
# one difference is that in female ATA chest type is also very common which is much more as compared to male

# %%
df_new=df[df["Sex"]=="M"]
df_new["FastingBS"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df_new=df[df["Sex"]=="F"]
df_new["FastingBS"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# in male fasting BS is present more as compared to females
# male 10 in 40 while female 5 in 40

# %%
df_new=df[df["Sex"]=="M"]
df_new["ExerciseAngina"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df_new=df[df["Sex"]=="F"]
df_new["ExerciseAngina"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# this shows while exercise 1 out of 2 people have chest pain while 1 out of 4 female 
# clearly men have more 2 times

# %%
df_new=df[df["Sex"]=="M"]
df_new["ST_Slope"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df_new=df[df["Sex"]=="F"]
df_new["ST_Slope"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# this shows female have mostly up while male mostly flat

# %%
df_new=df[df["Sex"]=="M"]
df_new["RestingECG"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df_new=df[df["Sex"]=="F"]
df_new["RestingECG"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# this one is also same almost 
# both have normal resting ECG around 6 in 10 and 2-3 in 10 in LVH while 1-2 in 10 in ST

# %%
sns.distplot(df[df["Sex"]=="M"]["Age"])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9716\996510234.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["Sex"]=="M"]["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df[df["Sex"]=="F"]["Age"])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9716\1031449005.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["Sex"]=="F"]["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df[df["Sex"]=="M"]["Age"].mean()
# Out:
# 53.78206896551724

# %%
df[df["Sex"]=="M"]["Age"].mode()
# Out:
# 0    54
# Name: Age, dtype: int64

# %%
df[df["Sex"]=="M"]["Age"].std()
# Out:
# 9.397863788104585

# %%
df[df["Sex"]=="M"]["Age"].skew()
# Out:
# -0.2311736514273209

# %%
df[df["Sex"]=="F"]["Age"].mean()
# Out:
# 52.49222797927461

# %%
df[df["Sex"]=="F"]["Age"].mode()
# Out:
# 0    54
# Name: Age, dtype: int64

# %%
df[df["Sex"]=="F"]["Age"].std()
# Out:
# 9.517592904603282

# %%
df[df["Sex"]=="F"]["Age"].skew()
# Out:
# -0.06473604018875663

# %%
# research done one 
# both are pretty same around 52 years 
# mostly at 54
# 43-62 yr more than 50% of people

# %%
df_new=df[df["HeartDisease"]==1]
df_new[df_new["Sex"]=="M"]["Age"].mean()
# Out:
# 55.86899563318777

# %%
df_new=df[df["HeartDisease"]==1]
df_new[df_new["Sex"]=="M"]["Age"].mode()
# Out:
# 0    58
# Name: Age, dtype: int64

# %%
df_new=df[df["HeartDisease"]==1]
df_new[df_new["Sex"]=="M"]["Age"].std()
# Out:
# 8.788561759891127

# %%
df_new=df[df["HeartDisease"]==1]
df_new[df_new["Sex"]=="M"]["Age"].skew()
# Out:
# -0.33590814331795177

# %%
df_new=df[df["HeartDisease"]==1]
df_new[df_new["Sex"]=="F"]["Age"].mean()
# Out:
# 56.18

# %%
df_new=df[df["HeartDisease"]==1]
df_new[df_new["Sex"]=="F"]["Age"].mode()
# Out:
# 0    62
# Name: Age, dtype: int64

# %%
df_new=df[df["HeartDisease"]==1]
df_new[df_new["Sex"]=="F"]["Age"].std()
# Out:
# 8.220655915039224

# %%
df_new=df[df["HeartDisease"]==1]
df_new[df_new["Sex"]=="F"]["Age"].skew()
# Out:
# -0.8755814792973433

# %%
# both male and female have average age 56yrs where HD starts
# women commonly get HD at 62 while men at 58 which shows men get earlier

# %%
sns.violinplot(data=df,x="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(data=df,x="Sex",y="HeartDisease")
# Out:
# <Axes: xlabel='Sex', ylabel='HeartDisease'>

# %%
sns.violinplot(data=df,x="RestingBP")
# Out:
# <Axes: xlabel='RestingBP'>

# %%
sns.violinplot(data=df,x="Cholesterol")
# Out:
# <Axes: xlabel='Cholesterol'>

# %%
sns.violinplot(data=df,x="MaxHR")
# Out:
# <Axes: xlabel='MaxHR'>

# %%
df.corr(numeric_only = True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
sns.jointplot(data=df,x="Age",y="HeartDisease")

# %%
sns.jointplot(data=df,x="Age",y="FastingBS")

# %%
sns.jointplot(data=df,x="Age",y="MaxHR")

# %%
sns.jointplot(data=df,x="Age",y="Oldpeak")

# %%
sns.jointplot(data=df,x="Age",y="Cholesterol")

# %%
sns.pairplot(df)
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
